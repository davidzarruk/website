# %%
import ast

a="[\n'select cast(''1970-01-01 '' || time as TIMESTAMP) as time\nfrom bostonboston_dynamo\n    where time != ''-''\n        and time not like ''%/%''\n        and time not like ''%NA%''\n        and country = ''USA''\n'\n]"
a = a.replace('\n', ' ')
result_list = ast.literal_eval(a)
print(result_list)
# Out:
# ['select cast(1970-01-01  || time as TIMESTAMP) as time from bostonboston_dynamo     where time != -         and time not like %/%         and time not like %NA%         and country = USA ']

# %%
a="[select cast('1970-01-01' || time as TIMESTAMP) as time from bostonbosto where country='COL']"
